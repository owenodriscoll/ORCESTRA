# %%
from S1_acquisition.src.file_download import check_for_new_file
from S1_acquisition.src.file_read import find_open_kml
from S1_acquisition.src.visualisation import plot_save_kml

# %%
check_for_new_file()

# %%
gdf, filename = find_open_kml() 
figure = plot_save_kml(gdf=gdf)
# Out:
# Attempting to load /Users/opodriscoll/Documents/Scripts/ORCESTRA/S1_acquisition/data/S1A_MP_USER_20240913T174000_20241003T194000.kml
